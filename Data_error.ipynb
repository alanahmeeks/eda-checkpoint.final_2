# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 



billboard_df= pd.read_csv('../billboard_data/billboardHot100_1999-2019.csv')
song_attributes_df= pd.read_csv('../billboard_data/songAttributes_1999-2019.csv')
grammy_albums_df=pd.read_csv('../billboard_data/grammyAlbums_199-2019.csv')
grammy_songs_df= pd.read_csv('../billboard_data/grammySongs_1999-2019.csv')
artist_df = pd.read_csv('../billboard_data/artistDf.csv')

# %%
billboard_df.head()
# Out:
#    Unnamed: 0                       Artists           Name  Weekly.rank  \
# 0           1                      Lil Nas,  Old Town Road            1
# 1           2  Shawn Mendes, Camila Cabello       Senorita            2
# 2           3                 Billie Eilish        Bad Guy            3
# 3           4                        Khalid           Talk            4
# 4           5     Ed Sheeran, Justin Bieber   I Don't Care            5
#
#    Peak.position  Weeks.on.chart    Week       Date  \
# 0            1.0             7.0  7/6/19   5-Apr-19
# 1            NaN             NaN  7/6/19  21-Jun-19
# 2            2.0            13.0  7/6/19  29-Mar-19
# 3            3.0            20.0  7/6/19   7-Feb-19
# 4            2.0             7.0  7/6/19  10-May-19
#
#                                                Genre  \
# 0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 1                                                Pop
# ...

# %%
test=billboard_df[(billboard_df['Weeks.on.chart']==1)]

test
# Out:
#        Unnamed: 0         Artists                   Name  Weekly.rank  \
# 592           593        Lil Nas,          Old Town Road            1
# 1584         1585  Jonas Brothers                 Sucker            1
# 2177         2178   Ariana Grande                7 Rings            1
# 3246         3247   Ariana Grande          Thank U, Next            1
# 3538         3539        Maroon 5         Girls Like You            1
# ...           ...             ...                    ...          ...
# 91825       91826           Janet  Doesn't Really Matter            1
# 93520       93521         Santana            Maria Maria            1
# 94171       94172        Lonestar                 Amazed            1
# 94357       94358    Mariah Carey  Thank God I Found You            1
# 95173       95174         Santana                 Smooth            1
#
#        Peak.position  Weeks.on.chart      Week       Date  \
# 592              1.0             1.0   5/25/19   5-Apr-19
# ...

# %%
test['Weekly.rank'].value_counts()
# Out:
# 1    116
# Name: Weekly.rank, dtype: int64

# %%
test['Peak.position'].value_counts()
# Out:
# 1.0    116
# Name: Peak.position, dtype: int64

# %%
billboard_df[(billboard_df['Weeks.on.chart']==2) & (billboard_df['Peak.position']==1)]
# Out:
#        Unnamed: 0                    Artists                   Name  \
# 493           494                   Lil Nas,          Old Town Road
# 1489         1490             Jonas Brothers                 Sucker
# 1683         1684  Lady Gaga, Bradley Cooper                Shallow
# 2078         2079              Ariana Grande                7 Rings
# 2374         2375      Post Malone, Swae Lee              Sunflower
# ...           ...                        ...                    ...
# 89085       89086                 Crazy Town              Butterfly
# 91733       91734                      Janet  Doesn't Really Matter
# 93426       93427                    Santana            Maria Maria
# 94079       94080                   Lonestar                 Amazed
# 95082       95083                    Santana                 Smooth
#
#        Weekly.rank  Peak.position  Weeks.on.chart      Week       Date  \
# 493              1            1.0             2.0    6/1/19   5-Apr-19
# ...
