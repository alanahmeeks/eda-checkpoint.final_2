# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset:
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 



billboard_df= pd.read_csv('../billboard_data/billboardHot100_1999-2019.csv')
song_attributes_df= pd.read_csv('../billboard_data/songAttributes_1999-2019.csv')
grammy_albums_df=pd.read_csv('../billboard_data/grammyAlbums_199-2019.csv')
grammy_songs_df= pd.read_csv('../billboard_data/grammySongs_1999-2019.csv')
artist_df = pd.read_csv('../billboard_data/artistDf.csv')

#So far, uploading pandas and numpy to perform numerical and exploratory analysis on the data files I've uploaded
# Not sure I will end up utilizing information from all of the different files available for this dataset on 
# kaggle, but importing the ones I think may be relevant in order to tell my data story in order to explore them
# and determine which ones will best contribute. 

# I've also uploaded the necessary libraries to handle the visualization of my data.

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
billboard_df.head()
# Out:
#    Unnamed: 0                       Artists           Name  Weekly.rank  \
# 0           1                      Lil Nas,  Old Town Road            1
# 1           2  Shawn Mendes, Camila Cabello       Senorita            2
# 2           3                 Billie Eilish        Bad Guy            3
# 3           4                        Khalid           Talk            4
# 4           5     Ed Sheeran, Justin Bieber   I Don't Care            5
#
#    Peak.position  Weeks.on.chart    Week       Date  \
# 0            1.0             7.0  7/6/19   5-Apr-19
# 1            NaN             NaN  7/6/19  21-Jun-19
# 2            2.0            13.0  7/6/19  29-Mar-19
# 3            3.0            20.0  7/6/19   7-Feb-19
# 4            2.0             7.0  7/6/19  10-May-19
#
#                                                Genre  \
# 0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 1                                                Pop
# 2  Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
# 3                                      Synth-Pop,Pop
# 4                      Canada,UK,Dance,Dance-Pop,Pop
#
#                                      Writing.Credits  \
# 0  Jozzy, Atticus ross, Trent reznor, Billy ray c...
# 1  Cashmere cat, Jack patterson, Charli xcx, Benn...
# 2                             Billie eilish, Finneas
# 3              Howard lawrence, Guy lawrence, Khalid
# 4  Ed sheeran, Justin bieber, Shellback, Max mart...
#
#                                               Lyrics         Features
# 0  Old Town Road Remix \nOh, oh-oh\nOh\nYeah, I'm...  Billy Ray Cyrus
# 1  Senorita \nI love it when you call me senorita...              NaN
# 2  bad guy \nWhite shirt now red, my bloody nose\...              NaN
# 3  Talk \nCan we just talk? Can we just talk?\nTa...              NaN
# 4  I Don't Care \nI'm at a party I don't wanna be...              NaN

# %%
billboard_df.info()

#making note of where data is missing... Peak.position and weeks.on.chart are two columns I plan on relying 
#heavily on in order to create a story about the data, will likely end up dropping those rows even though there
# are nearly 7,000 rows will null values in those categories. If the data is comprehensive, I should be able 
# to determine peak position and weeks on chart through some evaluating and fill those numbers in. 
# I will have to determine if it is worth the additional data after some looking around. 

# other potential problematic areas would be the date null values. 
# I had planned on utilizing the date column to look at the relationship between song release date and time to 
# get to number 1, but with nearly 13,000 rows of data missing on this one, I may have to reconsider. I will keep 
# the rows missing this information to utilize for other analyizing.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97225 entries, 0 to 97224
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       97225 non-null  int64
#  1   Artists          97225 non-null  object
#  2   Name             97225 non-null  object
#  3   Weekly.rank      97225 non-null  int64
#  4   Peak.position    90156 non-null  float64
#  5   Weeks.on.chart   90156 non-null  float64
#  6   Week             97225 non-null  object
#  7   Date             84978 non-null  object
#  8   Genre            97225 non-null  object
#  9   Writing.Credits  90012 non-null  object
#  10  Lyrics           97225 non-null  object
#  11  Features         21289 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 8.9+ MB

# %%
pct_missing=billboard_df.isna().mean()

pct_missing
# Out:
# Unnamed: 0         0.000000
# Artists            0.000000
# Name               0.000000
# Weekly.rank        0.000000
# Peak.position      0.072708
# Weeks.on.chart     0.072708
# Week               0.000000
# Date               0.125966
# Genre              0.000000
# Writing.Credits    0.074189
# Lyrics             0.000000
# Features           0.781034
# dtype: float64

# %%
#Exploring where I have null values and what that means for my analysis. 

null_dates=billboard_df[billboard_df['Date'].isnull()]

print(str(null_dates['Name'].nunique()), 'Number of songs missing the release date'+'\n'+str(null_dates.shape),'size of dataset with null values')

#There are nearly 1,000 songs that have a null value in the release date column that account for 12,000 rows.
# Out:
# 998 Number of songs missing the release date
# (12247, 12) size of dataset with null values

# %%
#print(type(null_dates['Name']))

null_date_songs=null_dates['Name'].unique()
print((null_date_songs))

#it struck me that having the songs with null values for date in a list may be helpful in determining use down 
# the line
# Out:
# ['All I Want For Christmas Is You' 'Jingle Bell Rock'
#  "Rockin' Around The Christmas Tree" 'A Holly Jolly Christmas'
#  'The Christmas Song' "It's The Most Wonderful Time Of The Year"
#  'Rudolph The Red' 'Last Christmas' 'Sleigh Ride' 'Here Comes Santa Claus'
#  'Feliz Navidad' 'Home For The Holidays' 'White Christmas'
#  'Blue Christmas' 'Christmas' 'Run Rudolph Run' 'Jingle Bells'
#  'Wonderful Christmastime' 'Bohemian Rhapsody' 'Thriller'
#  'Careless Whisper' 'Faith' 'Infinite' 'Hallelujah' 'I Know Somebody'
#  'Rock On' 'My Boo' 'Purple Rain' 'When Doves Cry' 'Little Red Corvette'
#  'Kiss' "Let's Go Crazy" '1999' 'Raspberry Beret' 'I Would Die 4 U'
#  'Little Bit Of You' 'I Love This Life' 'Die A Happy Man' 'Space Oddity'
#  'Under Pressure' 'God Only Knows' "I'm Comin' Over"
#  'Great Is Thy Faithfulness' 'Halo' 'Gonna Wanna Tonight'
#  'Straight Outta Compton' 'Sangria' 'Love You Like That'
#  'Love Is Your Name' 'Ulay, Oh' 'Please' 'Change My Mind'
#  'Stuck On A Feeling' 'Take It On Back' 'Out The Speakers'
#  'Somewhere In My Car' 'Blank Space' "My Baby's Got A Smile On Her Face"
#  'Soldier' 'Girl In A Country Song' 'The Old Rugged Cross'
#  "The Blower's Daughter" 'I Walk The Line' "I'm Not Gonna Miss You"
#  'This Is How We Roll' 'My Eyes' 'Whiskey In My Water'
#  "Keep Them Kisses Comin'" 'Jungle' 'Billie Jean' 'Achy Breaky 2'
#  "That's My Kind Of Night" 'Bridge Over Troubled Water'
#  "Livin' On A Prayer" 'Give It 2 U' 'Outta My Head'
#  'Little Bit Of Everything' 'All Over The Road' 'Could It Be' 'Wop'
#  'Born To Fly' 'Maybe It Was Memphis' "I Can't Tell You Why" 'Who I Am'
#  'Levitate' 'Kisses Down Low' 'I Am Beautiful' 'Dope' 'Buzzkill'
#  'Die Young' 'Crying On A Suitcase' 'Let There Be Cowgirls'
#  'I Dreamed A Dream' 'Kiss Tomorrow Goodbye' 'On My Own'
#  'I Want To Know What Love Is' 'Fade Into You' "Shinin' On Me" 'Over'
#  "That's Why I Pray" 'Drunk On You' 'Even If It Breaks Your Heart'
#  'Beers Ago' 'Ayy Ladies' "We've Got Tonight" 'Got My Country On'
#  'Yesterday' 'Roxanne' 'Where I Come From' 'You Gonna Fly'
#  'Do It Like You' "Love's Gonna Make It Alright" 'I Will Always Love You'
#  "What Doesn't Kill You" 'I Wanna Dance With Somebody'
#  'Greatest Love Of All' 'How Will I Know' 'Brighter Than The Sun'
#  'Without You' 'We Found Love' "Moves Like Jagger / Jumpin' Jack Flash"
#  'The First Time Ever I Saw Your Face' 'Amen' 'Tattoo' 'The Champ'
#  'When We Stand Together' 'God Gave Me You' 'In The Dark'
#  'Survivor / I Will Survive' "I Got Nothin'" 'El Verdadero Amor Perdona'
#  'You And I / You And I' 'Hit Me With Your Best Shot / One Way Or Another'
#  'Here For A Good Time' 'Made In America' 'Faster' 'Pretty Girls'
#  "Love Don't Run" 'Fish' 'Far Away' 'I Smile' 'Racks' 'What If'
#  'Stitch By Stitch' 'Man In The Mirror' 'Losing My Religion'
#  'Somewhere Else' 'Like My Mother Does' 'Cat Daddy' 'Feels So Good'
#  'Look It Up' 'This' 'Time After Time' 'Family Man' 'All By Myself'
#  'Where You At' 'Georgia Clay' 'Walking' 'This Is Country Music'
#  "Who Are You When I'm Not Looking" 'Voices'
#  'Someone Else Calling You Baby' 'Twisted' 'Hit The Lights'
#  'Put You In A Song' 'Boyfriend' 'Make It Rain' 'Bullets In The Gun'
#  'The Breath You Take' 'Turn On The Radio' 'Anything Like Me' 'Big Night'
#  'Welcome Christmas' 'One In A Million' 'Come Back Song' 'Liv Tonight'
#  'Sick' "If It's Love" 'Way Out Here' 'All About Tonight'
#  'Only The Good Die Young' 'Papa Can You Hear Me?'
#  'Hope She Cheats On You' 'What I Did For Love' 'Smile' 'Trailerhood'
#  'Dumb Love' "I'm In" "This Ain't Nothin'" 'Lose My Mind'
#  'Rain Is A Good Thing' 'Pray For You' "We'll Be A Dream"
#  'The Man I Want To Be' 'I Gotta Get To You' "Keep On Lovin' You"
#  'Good Vibrations' 'Beautiful Day' 'Up To The Mountain' "Jessie's Girl"
#  'Super High' 'Pyramid' 'Ice Ice Baby' 'Hillbilly Bone' 'Reverse Cowgirl'
#  'History In The Making' 'Driving Me Crazy' "Cryin' For Me" 'Rain'
#  'Consider Me Gone' 'Lean On Me' 'Breathless' 'Stranded'
#  'My City Of Ruins' 'Let It Be' 'Hurry Home' 'Wasted' "Gettin' You Home"
#  'Bonfire' 'Twang' "It's Your Life" 'Only You Can Love Me This Way'
#  'Whatever You Like' 'Face Drop' 'Halo / Walking On Sunshine'
#  'Sounds Like Life To Me' "I'm In Miami Trick" 'Living For The Night'
#  "I'll Just Hold On" 'Fire Burning' 'Alright' 'Barefoot And Crazy'
#  'Blame It' 'One In Every Crowd' "Where I'm From" 'I Told You So'
#  'Apologize' 'Falling Slowly' "It Won't Be Like This For Long" 'Soulmate'
#  'Candle' 'River Of Love' 'Move' 'Ride' 'You Complete Me' 'Just Like Me'
#  'Things That Matter' 'Love Who You Love' 'Sweet Thing'
#  "She Wouldn't Be Gone" 'Love Is On Its Way' 'Break My Heart'
#  'Top Of The World' 'Let Me' 'Roll With Me' 'All Summer Long' 'Swing'
#  'No Me Doy Por Vencido' 'Need U Bad' 'Do You Believe Me Now'
#  'Too Drunk...' 'Angel' 'Angels' 'Cuddy Buddy' 'All I Ever Wanted' 'Be OK'
#  'Magic' 'The Business' 'Holler Back' "I'd Rather Be With You" 'Real'
#  'What If It All Goes Right' 'Summertime' 'Back When I Knew It All'
#  'Sexy Can I' "I'm Still A Guy" "Stepped On My J'z" 'That Song In My Head'
#  'I Saw God Today' "She's A Hottie" 'Always Be My Baby'
#  "Hollywood's Not America" 'Killa' 'Boyfriend/Girlfriend' 'Dey Know'
#  'Sweet And Low' 'Take You There' 'Never' 'Praying For Time'
#  'Many Rivers To Cross' "It's Good To Be Us" 'Got Me Going'
#  'Cleaning This Gun' 'Diamond Girl' 'God Must Be Busy'
#  'Watching Airplanes' 'Winner At A Losing Game' "I'll Be Waiting"
#  'Get My Drink On' 'Girls In Their Summer Clothes' 'Anyone Else But You'
#  'Witch Doctor' 'Freaky Gurl' 'Bad Day' 'Funkytown' 'The Chipmunk Song'
#  'Me Love' "Livin' Our Love Song" 'Free And Easy' 'Hood Figga'
#  'Take Me There' 'Online' 'Love Me If You Can' 'Famous In A Small Town'
#  'These Are My People' 'Make Me Better' 'Lean Like A Cholo' 'Easy'
#  'What Time Is It' 'A Different World' 'Find Out Who Your Friends Are'
#  'Wrapped' "Before It's Too Late" 'Guys Like Me' "I'm A Flirt" 'Lost'
#  'Imagine' 'If Everyone Cared' 'You Give Love A Bad Name'
#  'High Maintenance Woman' 'Beautiful Flower' 'Vulnerable' 'Signal Fire'
#  'On The Hotline' "It's Me Snitches" "A Feelin' Like That" 'Get Buck'
#  'Lips Of An Angel' 'King Kong' '1st Time' 'Boston' 'Watching You'
#  'Nothing Left To Lose' 'Walk Away' "Movin' On" 'The Neighbor'
#  'Freak On A Leash' 'Keep Your Mind Wide Open' 'Not Fade Away'
#  'Streetcorner Symphony' 'Crazy Car' 'Money In The Bank' 'My, Oh My'
#  'My Wish' 'Unappreciated' 'Some People Change' 'Hate'
#  "I'll Be Home For Christmas" 'Give It Away' 'Dangerous' 'The Riddle'
#  'I Know You See It' 'A La Primera Persona' 'Change Me'
#  'Crash Here Tonight' 'Tengo Un Amor' "If You're Going Through Hell"
#  'Superman' 'Crazy Bitch' 'Sunshine And Summertime'
#  'Feels Just Like It Should' 'Sleep On It' 'A Little Too Late'
#  'Labios Compartidos' "Life Ain't Always Beautiful" 'Doing Too Much'
#  'Crowded' 'Hanging On' 'Last Day Of My Life' "How 'Bout You"
#  'Somewhere Over The Rainbow' "Scotty Doesn't Know" 'Let U Go'
#  'My Destiny' "Ridin' Rims" 'Size Matters' "I Can't Unlove You"
#  'Girl Next Door' "Takin' It To The Streets" 'Wanted Dead Or Alive'
#  'Good Luck Charm' 'Wherever You Are' 'Soundtrack To Your Life'
#  'The Lucky One' 'Get Drunk And Be Somebody' 'Touch It' 'In My Mind'
#  'Again And Again' 'Beautiful Love' 'Nobody But Me' 'Always On Your Side'
#  "She Don't Tell Me To" 'Looking For You' "When I Get Where I'm Going"
#  'Lo Que Me Gusta A Mi' "Cheatin'" 'Oh Yes' "Betcha Can't Do It Like Me"
#  'In The Deep' 'Turn It Up' 'She Let Herself Go'
#  'Cowboys Are Frequently Secretly' 'Like We Never Loved At All'
#  'In The Sun' 'We Belong Together' 'Miss Me Baby' 'Seasons Of Love' 'Skin'
#  'More Than Words' 'Amor Eterno' 'Something To Be Proud Of'
#  'Just The Girl' 'Good Is Good' "You're Like Comin' Home"
#  'A Real Fine Place To Start' 'If You Were Mine' 'Shine On'
#  'All Jacked Up' 'Mississippi Girl' 'Juicebox' 'Footprints'
#  'Make Her Feel Good' 'Good Times' 'How To Deal' 'Help Somebody'
#  'Dem Boyz' "Don't Worry 'Bout A Thing" 'Nada Es Para Siempre'
#  "I Can't Stop Loving You" "You'll Be There" 'Goodbye Time' 'My Sister'
#  "Sgt. Pepper's Lonely Hearts Club Band" 'If Something Should Happen'
#  "Don't Ask Me How I Know" 'How Could You' 'All Because Of You' 'Gone'
#  'Homewrecker' "What's A Guy Gotta Do" 'If Heaven'
#  "I'll Take That As A Yes" 'Let Them Be Little' "Bitches Ain't shit"
#  'Trying To Find Atlantis' 'Awful, Beautiful Life' 'Some Beach' 'Landed'
#  "When I Think About Cheatin'" 'Balla Baby' 'Perdidos' 'Gotta Go Solo'
#  "You're The One" 'Nothing On But The Radio' 'Lean Back' 'Come Home Soon'
#  'In A Real Love' 'Nolia Clap' "That's What It's All About"
#  "Let's Get It Started" 'Suds In The Bucket' 'Big Chips' 'Stays In Mexico'
#  'Sunshine' 'She Thinks She Needs Me' 'Nasty Girl' 'Feels Like Today'
#  'Turn Me On' 'I Like That' 'Still In Love' 'Away From The Sun' 'Somebody'
#  'Whiskey Girl' 'I Believe' 'Freaks' 'How Did You Know?'
#  'If You Ever Stop Loving Me' "Hey Good Lookin'" "Let's Be Us Again"
#  'Jook Gal' 'Everything' 'Dude' 'Ch' 'Get No Better'
#  "Where Are We Runnin'?" 'Passenger Seat' 'Coo' 'Desperately'
#  'Last One Standing' 'One Call Away' 'Ride Wit U' 'Solitaire'
#  'Simple Life' 'American Soldier' 'Songs About Rain'
#  'When I Look To The Sky' 'F.U.R.B.' 'In My Life' 'Gal Yuh Ah Lead' 'You'
#  'Love Me Right' 'I Can Only Imagine' 'Invisible' 'Alone' 'Pull Up'
#  'Still Frame' 'Hell Yeah' "Drinkin' Bone" 'My Baby' 'Not Today' 'Honesty'
#  'Badaboom' 'Pop That Booty' 'Cowboys Like Us' 'Knock Knock'
#  'I Love This Bar' 'Wave On Wave' 'Tough Little Boys' 'Party To Damascus'
#  'I Need You Now' 'Naggin' 'Hole In The World' 'A Few Questions'
#  'This Is The Night' 'Rest In Pieces' 'Sympathy For The Devil'
#  "Rubberneckin'" 'Simply Being Loved' "Roun' The Globe"
#  'My Front Porch Looking In' 'Stay Gone' 'Flying Without Wings'
#  "Feelin' Freaky" 'What The World Needs' 'Snake' 'The Love Song' 'Speed'
#  'Tell Me Something Bad About Tulsa' 'Have You Forgotten?' 'I Love You'
#  'Emotional Rollercoaster' 'Girlfriend' 'Step Daddy'
#  "No One's Gonna Change You" "Soldier's Heart" 'Sick Of Being Lonely'
#  "Blowin' Me Up" 'Always' "Don't Dream It's Over" 'Tell Me' 'That Girl'
#  'Laundromat' "You Can't Hide Beautiful" 'Rock You Baby' "Can't Nobody"
#  'Fall Into Me' 'Do That...' 'I Should Be...' 'Beautiful Goodbye'
#  "I Wish You'd Stay" 'In A Little While' 'Breathe' 'Unusually Unusual'
#  'Take You Home' "Who's Your Daddy?" 'Rock The Party'
#  'Somewhere Out There' 'These Are The Days' "Po' Folks"
#  'Where Would You Be' 'Little Things' 'Gotta Get Thru This' 'Trade It All'
#  'Starry Eyed Surprise' 'Forgive' 'American Child' 'Flake'
#  'Ten Rounds With Jose Cuervo' 'No Such Thing' 'Downfall'
#  'When You Lie Next To Me' 'The Impossible' 'Big Machine' "I've Got You"
#  'Out Of My Heart' 'The One' "I'm Gonna Miss Her"
#  'Tonight I Wanna Be Your Man' 'Blue Jeans' 'For All Time'
#  'Not A Day Goes By' 'Quitame Ese Hombre' 'Give It To Her' 'Too Bad'
#  'I Should Be Sleeping' "Black Suits Comin'" "I Don't Want You To Go"
#  "That's When I Love You" 'My List' 'Roc The Mic'
#  'I Breathe In, I Breathe Out' 'Take A Message' 'Sugarhigh'
#  'Some Days You Gotta Dance' 'Whoa Now' "I Told Y'all" "It's Goin' Down"
#  'Any Other Night' 'No Matta What' 'Feel The Girl' 'Wrapped Around'
#  'In Another World' 'Alive' 'Just Let Me Be In Love' 'Defy You' 'Run'
#  'Wrapped Up In You' 'Part II' 'Ooohhhwee' 'Goodbye' 'Runaway'
#  'My Sweet Lord' 'Dance With Me' 'God Bless The USA'
#  'The Star Spangled Banner' 'God Bless America' "What's Going On"
#  "Can't Deny It" "I'm A Believer" 'Castles In The Sky' 'Drive'
#  'Just In Case' "I'll Fly With You" 'Start The Commotion'
#  'What I Really Meant To Say' 'John Doe' 'My Projects' 'Sandstorm'
#  "She's All I Got" "Don't Mess With The Radio" 'Two People Fell In Love'
#  'Right Where I Need To Be' 'La Bomba' 'Miss California'
#  'If You Can Do Anything Else' 'Midwest Swing' 'Oochie Wally'
#  "If I Fall You're Going Down With Me" 'South Side' 'Look At Us'
#  'Get Over Yourself' 'Mrs. Steven Rudy' 'Bizounce' "Everybody Doesn't"
#  'Best I Ever Had' 'Butterfly' 'Around The World' 'Stranger In My House'
#  'If My Heart Had Wings' 'The Way You Love Me' 'After Party'
#  'She Misses Him' 'Rose Bouquet' 'My Everything' 'One Woman Man'
#  'With Arms Wide Open' 'Babylon' 'Tell Her' 'Wild Horses'
#  'A Good Day To Run' 'Project Chick' 'So In Love With Two'
#  'My Next Thirty Years' 'We Danced' 'Still On Your Side' 'Georgia'
#  'Mamacita' 'Meanwhile Back At The Ranch' "You Should've Told Me" 'Liar'
#  'The Itch' 'Feels Like Love' "You're A God" 'The Christmas Shoes'
#  'Open My Heart' 'I Know' 'Kiss This' 'If I Am' 'Faded'
#  "You Won't Be Lonely Now" 'That Other Woman' 'Higher' 'There You Are'
#  'Summer Rain' 'Californication' 'I Will...But' 'Change Your Mind'
#  'Deep Inside Of You' "Don't Call Me Baby" "It's Always Somethin'"
#  "Let's Make Love" 'Country Comes To Town' 'What You Want' 'Absolutely'
#  'Desert Rose' "That's The Way" 'Everything You Want' "Toca's Miracle"
#  'One Voice' "You'll Always Be Loved By Me" 'Whatever' 'Purest Of Pain'
#  'I Will Love Again' 'Sour Girl' 'Ta Da' "I'll Be" 'When You Need My Love'
#  'Flowers On The Wall' 'Kernkraft 400' 'Smooth' "Big Pimpin'"
#  'Where I Wanna Be' 'Broadway' 'As We Lay' 'The Chain Of Love'
#  'West Side Story' 'I Think God Can Explain' 'I Try' 'Amazed'
#  'Better Off Alone' 'Swear It Again' 'Same Script, Different Cast'
#  'Some Things Never Change' 'Wobble Wobble' 'Thong Song' 'Maria Maria'
#  'Unconditional' 'Shackles' 'Take That' 'Dancing Queen' 'Say My Name'
#  "Couldn't Last A Moment" '3 Little Words' 'Someday Out Of The Blue'
#  "She's More" 'Buy Me A Rose' 'What I Need To Do' 'Carlene' 'Monica'
#  'Otherside' 'More' 'You Owe Me' 'It Feels So Good' 'Only God Knows Why'
#  'Been There' 'Never Let You Go' "Love's The Only House"
#  'Another Nine Minutes' 'Give Me You'
#  'Show Me The Meaning Of Being Lonely' 'I Need To Know' 'The Best Day'
#  'No Me Dejes De Querer' 'I Like It' 'From The Bottom Of My Broken Heart'
#  'Lessons Learned' 'I Knew I Loved You' 'Forgot About Dre' 'Me Neither'
#  'The Bad Touch' 'Get It On Tonite' 'Falls Apart' "That's The Way It Is"
#  'I Belong To You' 'No Mercy' "I Don't Wanna Kiss You Goodnight"
#  'I Need A Hot Girl' 'Bring It All To Me' 'What A Girl Wants'
#  'Back At One' 'Mr. Too Damn Good' 'It Was' "U Don't Love Me"
#  'I Learned From The Best' 'Then The Morning Comes' "He Can't Love U"
#  'Blue' 'Because You Love Me' 'My Best Friend' 'Stay Or Let It Go'
#  "Can't Stay" 'No More Rain' 'Take A Picture' 'Meet Virginia'
#  'Cowboy Take Me Away' "Daddy Won't Sell The Farm" 'This Woman Needs'
#  'Got To Get It' 'Re' 'Do What You Gotta Do' 'The Best Man I Can Be'
#  'The Great Beyond' 'Dear Lie' 'Rhythm Divine' "What's My Name"
#  'Hanginaround' '24/7' 'None Of Ur Friends Business' 'Shake Your Bon'
#  'If You Love Me' 'Put Your Hand In Mine' 'My Love Is Your Love'
#  'What Do You Say' 'Candy' 'Girl On TV' 'Do It Again' 'U Understand'
#  'Guerrilla Radio' 'Pop A Top' "U Know What's Up" 'Learn To Fly'
#  'Got Your Money' "He Didn't Have To Be" 'Black Balloon'
#  'I Wanna Love You Forever' 'Big Deal' 'Waiting For Tonight'
#  'When I Said I Do' "Dancin'" 'Stay The Night' 'You Can Do It'
#  'Caught Out There' 'Smoke Rings In The Dark' 'Deep Inside'
#  'Where My Girls At?' 'Tricky, Tricky' 'Home To You'
#  'The Chemicals Between Us' '4, 5, 6' 'Tha Block Is Hot' 'N 2 Gether Now'
#  'L.A. Song' 'Someday' "The Quittin' Kind" 'Bug A Boo'
#  "Don't Say You Love Me" 'Still D.R.E.' "She Thinks My Tractor's Sexy"
#  'Unpretty' 'Steal My Sunshine' 'All Things Considered' 'Crazy'
#  'Auld Lang Syne' 'There She Goes' 'Larger Than Life'
#  'The Rockafeller Skank' "We Can't Be Friends" 'Music Of My Heart'
#  'Will 2K' 'Get Gone' 'Heartbreaker' '15 Minutes' 'This Gift'
#  'Give You What You Want' 'The Greatest Romance Ever Sold'
#  'Deck The Halls' 'Gotta Man' 'Steam' 'NAStradamus' "She's So High"
#  'Something Like That' 'Come On Over' 'I Want It All' 'Genie In A Bottle'
#  'Scar Tissue' 'I Do' "She's All I Ever Had" "The Dolphin's Cry"
#  'What Do You Say To That' 'If I Could Turn Back The Hands Of Time'
#  'All Star' "I'm Already Taken" 'Beauty' 'American Woman' "I'll Go Crazy"
#  "A Man Ain't Made Of Stone" 'Spend My Life With You' 'Vivrant Thing'
#  'Angels Would Fall' "What's My Age Again?" 'So Anxious' 'Cowboy'
#  'Man! I Feel Like A Woman!' 'I Want It That Way' 'Bailamos'
#  'You Had Me From Hello' 'Ready To Run' 'Simon Says'
#  'Never Gonna Let You Go' 'Out Of My Head' 'Lightning Does The Work'
#  "You'll Be In My Heart" "She's In Love" 'What Ya Want'
#  'Meeting In My Bedroom' 'I Could Not Ask For More' 'Summer Girls'
#  "It's All About You" 'If You Had My Love' 'Bills, Bills, Bills'
#  'Missing You' 'Wanna Be A Baller' 'Little Man' "I'll Still Love You More"
#  'Jamboree' 'All That I Can Say' 'The Secret Of Life' 'Last Kiss'
#  "Lesson In Leavin'" 'Happily Ever After' "Now You Don't"
#  "I'll Be Your Everything" 'Everyone Falls In Love'
#  'Everything Is Everything' 'Beautiful Stranger' "Tell Me It's Real"
#  'Better Days' 'God Must Have Spent A Little More Time On You' 'Nookie'
#  'I Love You Came Too Late' "You've Got A Way" 'I Will Remember You'
#  'Sometimes' 'Never Been Kissed' 'Fortunate' 'Single White Female'
#  'A Night To Remember' 'Kiss Me' 'Little Good' 'I Will Go With You'
#  'Bliss' 'Lately' 'Whatever You Say' "Chante's Got A Man"
#  'Did You Ever Think' 'Who Needs Pictures' 'Watch Out Now'
#  'The Hardest Thing' 'Anywhere' 'Write This Down' 'My Own Worst Enemy'
#  "Almost Doesn't Count" 'The Day The World Went Away' 'Who Dat'
#  'No Scrubs' "Livin' La Vida Loca" '808' 'Almost Home'
#  "Tonight The Heartache's On Me" 'Players Holiday' 'Rollercoaster'
#  "It's Your Thing" 'You Are Everything' 'Better Than Me'
#  'Crazy Little Thing Called Love' "That Don't Impress Me Much"
#  'Holla Holla' 'Please Remember Me' 'Give It To You' 'Two Teardrops'
#  'Every Morning' "You Won't Ever Be Lonely" 'With You' 'Strong Enough'
#  'Slide' "What It's Like" 'One Honest Heart' 'My Favorite Girl'
#  'Slave To The Habit' 'If You' 'Praise You' 'Anyone Else' 'Nann' 'Believe'
#  'Wish You Were Here' "She's Always Right" 'Heavy'
#  "Why Don't You Get A Job?"]

# %%
#isolating the records with null values for Peak.position to see if this lines ups with the Weeks.on.chart null
#  values. 

null_position=billboard_df[billboard_df['Peak.position'].isnull()]


null_position.head()
# Out:
#     Unnamed: 0                       Artists             Name  Weekly.rank  \
# 1            2  Shawn Mendes, Camila Cabello         Senorita            2
# 15          16                     Lil Nas X           Panini           16
# 19          20                   Nicki Minaj         MEGATRON           20
# 21          22            Lil Nas X, Cardi B            Rodeo           22
# 55          56        Marshmello, Kane Brown  One Thing Right           57
#
#     Peak.position  Weeks.on.chart    Week       Date  \
# 1             NaN             NaN  7/6/19  21-Jun-19
# 15            NaN             NaN  7/6/19  20-Jun-19
# 19            NaN             NaN  7/6/19  21-Jun-19
# 21            NaN             NaN  7/6/19  21-Jun-19
# 55            NaN             NaN  7/6/19  21-Jun-19
#
#                                                 Genre  \
# 1                                                 Pop
# 15                     Memes,Atlanta,Hip-Hop,Trap,Rap
# 19                             East Coast,Hip-Hop,Rap
# 21  Country,Atlanta,East Coast,Trap,Country Rap,Hi...
# 55                                                Pop
#
#                                       Writing.Credits  \
# 1   Cashmere cat, Jack patterson, Charli xcx, Benn...
# 15  Dot da genius, Kurt cobain, David biral, Denze...
# 19  Haldane brown, Andrew pop wansel, Brittany con...
# 21  Denzel baptiste, Russ chell, Roy lenzo, Cardi ...
# 55  Josh hoge, Jesse frasure, Matt mcginn, Marshme...
#
#                                                Lyrics Features
# 1   Senorita \nI love it when you call me senorita...      NaN
# 15  Panini \nDaytrip took it to 10 Hey\nAyy, Panin...      NaN
# 19  MEGATRON \nBrra-ta-ta-ta\nBrra-ta-ta-ta\nThey ...      NaN
# 21  Rodeo \nDaytrip took it to 10 Hey\nOh, here we...      NaN
# 55  One Thing Right \nI've cheated and I've lied\n...      NaN

# %%
#The same set of records have null values for both Peak.poisiton and Weeks.on.chart

null_position.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7069 entries, 1 to 97223
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       7069 non-null   int64
#  1   Artists          7069 non-null   object
#  2   Name             7069 non-null   object
#  3   Weekly.rank      7069 non-null   int64
#  4   Peak.position    0 non-null      float64
#  5   Weeks.on.chart   0 non-null      float64
#  6   Week             7069 non-null   object
#  7   Date             6164 non-null   object
#  8   Genre            7069 non-null   object
#  9   Writing.Credits  6422 non-null   object
#  10  Lyrics           7069 non-null   object
#  11  Features         1577 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 717.9+ KB

# %%
null_position.shape
# Out:
# (7069, 12)

# %%
print(str(null_position['Name'].nunique()),' - number of unique songs titles that have null values for peak position and weeks on chart')

print(str(billboard_df['Name'].nunique()), ' - total unique songs for the whole data set')


#This tells me the NaN values may be related to the first week the songs make an appearance on the list. 
# for nearly all of the total songs of the dataset to be included. But that doesn't tell me why some appear 
# more than once. I have already ruled out duplicate rows. There don't appear to be any.
# Out:
# 6339  - number of unique songs titles that have null values for peak position and weeks on chart
# 6458  - total unique songs for the whole data set

# %%
null_position['Week'].value_counts()

#checking to see if there was any correlation to the error and the week date. 
# The data set tracks billboard song records through July 2019.... I will have to consider a way to remove songs
# that appear for the first time too late in the data set or it could skew my data. That explains some of the 
# missing data I'm finding in this category but not all.
# Out:
# 7/14/18     27
# 12/15/18    26
# 4/8/17      24
# 10/13/18    24
# 9/16/17     19
#             ..
# 1/11/06      1
# 7/8/03       1
# 1/12/05      1
# 11/20/01     1
# 9/9/03       1
# Name: Week, Length: 1042, dtype: int64

# %%
billboard_df.describe()

#making note of the mean anad quartiles for peak.position and weeks.on.chart.
# Out:
#          Unnamed: 0   Weekly.rank  Peak.position  Weeks.on.chart
# count  97225.000000  97225.000000    90156.00000    90156.000000
# mean   48613.000000     50.452373       36.58665       12.542948
# std    28066.584298     28.816813       27.36506        9.123191
# min        1.000000      1.000000        1.00000        0.000000
# 25%    24307.000000     26.000000       11.00000        6.000000
# 50%    48613.000000     50.000000       33.00000       11.000000
# 75%    72919.000000     75.000000       59.00000       17.000000
# max    97225.000000    100.000000      100.00000       87.000000

# %%
billboard_df.duplicated().value_counts()
#Good to see there are not any duplicated rows
# Out:
# False    97225
# dtype: int64

# %%
billboard_df['Name'].nunique()
#of the 97,000+ rows, there are roughly 6458 songs that make an appearance.
# Out:
# 6458

# %%
#Changing the data type of the Week date in order to easily break out the year for evaluation.


billboard_df['Week']= pd.to_datetime(billboard_df['Week'])

billboard_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97225 entries, 0 to 97224
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       97225 non-null  int64
#  1   Artists          97225 non-null  object
#  2   Name             97225 non-null  object
#  3   Weekly.rank      97225 non-null  int64
#  4   Peak.position    90156 non-null  float64
#  5   Weeks.on.chart   90156 non-null  float64
#  6   Week             97225 non-null  datetime64[ns]
#  7   Date             84978 non-null  object
#  8   Genre            97225 non-null  object
#  9   Writing.Credits  90012 non-null  object
#  10  Lyrics           97225 non-null  object
#  11  Features         21289 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(7)
# memory usage: 8.9+ MB

# %%
#putting Year as a separate column for evaluation down the line.

billboard_df['Year']=billboard_df['Week'].dt.year

billboard_df['Month']= billboard_df['Week'].dt.month

billboard_df.head()
# Out:
#    Unnamed: 0                       Artists           Name  Weekly.rank  \
# 0           1                      Lil Nas,  Old Town Road            1
# 1           2  Shawn Mendes, Camila Cabello       Senorita            2
# 2           3                 Billie Eilish        Bad Guy            3
# 3           4                        Khalid           Talk            4
# 4           5     Ed Sheeran, Justin Bieber   I Don't Care            5
#
#    Peak.position  Weeks.on.chart       Week       Date  \
# 0            1.0             7.0 2019-07-06   5-Apr-19
# 1            NaN             NaN 2019-07-06  21-Jun-19
# 2            2.0            13.0 2019-07-06  29-Mar-19
# 3            3.0            20.0 2019-07-06   7-Feb-19
# 4            2.0             7.0 2019-07-06  10-May-19
#
#                                                Genre  \
# 0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 1                                                Pop
# 2  Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
# 3                                      Synth-Pop,Pop
# 4                      Canada,UK,Dance,Dance-Pop,Pop
#
#                                      Writing.Credits  \
# 0  Jozzy, Atticus ross, Trent reznor, Billy ray c...
# 1  Cashmere cat, Jack patterson, Charli xcx, Benn...
# 2                             Billie eilish, Finneas
# 3              Howard lawrence, Guy lawrence, Khalid
# 4  Ed sheeran, Justin bieber, Shellback, Max mart...
#
#                                               Lyrics         Features  Year  \
# 0  Old Town Road Remix \nOh, oh-oh\nOh\nYeah, I'm...  Billy Ray Cyrus  2019
# 1  Senorita \nI love it when you call me senorita...              NaN  2019
# 2  bad guy \nWhite shirt now red, my bloody nose\...              NaN  2019
# 3  Talk \nCan we just talk? Can we just talk?\nTa...              NaN  2019
# 4  I Don't Care \nI'm at a party I don't wanna be...              NaN  2019
#
#    Month
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7

# %%
all_songs=billboard_df.copy()
#all_songs=all_songs.groupby(['Name','Artists','Peak.position']).agg(avg_weekly_rank=('Weekly.rank',np.mean), total_weeks=('Weeks.on.chart','max'), year=('Year','min'))

#all_songs
all_songs=all_songs.groupby(['Name','Artists']).agg(top_spot=('Peak.position','min'),avg_weekly_rank=('Weekly.rank',np.mean), total_weeks=('Weeks.on.chart','max'), year=('Year','min'))

all_songs
# Out:
#                                          top_spot  avg_weekly_rank  \
# Name                    Artists
# '03 Bonnie & Clyde      Jay                   4.0        16.478261
# ...Ready For It?        Taylor Swift          4.0        41.736842
# 0 To 100 / The Catch Up Drake                35.0        48.000000
# 1                       800                   3.0        34.414634
# 1 Thing                 Amerie                8.0        38.900000
# ...                                           ...              ...
# m.A.A.d City            Kendrick Lamar       75.0        89.000000
# sobeautiful             Musiq Soulchild      84.0        90.636364
# whoa                    XXXTENTACION         37.0        70.666667
# whoknows                Musiq                65.0        84.461538
# www.memory              Alan Jackson         45.0        63.400000
#
#                                          total_weeks  year
# Name                    Artists
# '03 Bonnie & Clyde      Jay                     23.0  2002
# ...Ready For It?        Taylor Swift            20.0  2017
# 0 To 100 / The Catch Up Drake                   20.0  2014
# 1                       800                     42.0  2017
# 1 Thing                 Amerie                  20.0  2005
# ...                                              ...   ...
# m.A.A.d City            Kendrick Lamar           3.0  2012
# sobeautiful             Musiq Soulchild         11.0  2009
# whoa                    XXXTENTACION             3.0  2018
# whoknows                Musiq                   13.0  2004
# www.memory              Alan Jackson            15.0  2000
#
# [7213 rows x 4 columns]

# %%
#isolating songs that hit number one to analyze

billboard_number_one= billboard_df.copy()
billboard_number_one= billboard_number_one[(billboard_number_one['Peak.position']== 1.0)]

billboard_number_one.shape

#here I am checking to see how many records of songs show peak position as #1 to get an idea of the size of the 
#  data I want to work with. I think I'm going to focus on this subset of the data.
# Out:
# (5566, 14)

# %%
billboard_number_one.head()
# Out:
#     Unnamed: 0                Artists           Name  Weekly.rank  \
# 0            1               Lil Nas,  Old Town Road            1
# 5            6         Jonas Brothers         Sucker            6
# 11          12  Post Malone, Swae Lee      Sunflower           12
# 16          17                 Halsey     Without Me           17
# 22          23          Ariana Grande        7 Rings           23
#
#     Peak.position  Weeks.on.chart       Week       Date  \
# 0             1.0             7.0 2019-07-06   5-Apr-19
# 5             1.0            17.0 2019-07-06   1-Mar-19
# 11            1.0            36.0 2019-07-06  18-Oct-18
# 16            1.0            38.0 2019-07-06   4-Oct-18
# 22            1.0            23.0 2019-07-06  18-Jan-19
#
#                                                 Genre  \
# 0   Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 5      Alternative Pop,Boy Band,Teen Pop,Pop-Rock,Pop
# 11      Rap,Disney,Hip-Hop,Marvel,Soundtrack,R&;B,Pop
# 16  Synth-Pop,R&;B,Alternative Pop,Ballad,Pop,Alte...
# 22                                Memes,Trap,R&;B,Pop
#
#                                       Writing.Credits  \
# 0   Jozzy, Atticus ross, Trent reznor, Billy ray c...
# 5   Ryan tedder, Louis bell, Frank dukes, Nick jon...
# 11  Carl rosen, Louis bell, Billy walsh, Carter la...
# 16  Justin timberlake, Timbaland, Halsey, Delacey,...
# 22  Ariana grande, Richard rodgers, Tbhits, Njomza...
#
#                                                Lyrics         Features  Year  \
# 0   Old Town Road Remix \nOh, oh-oh\nOh\nYeah, I'm...  Billy Ray Cyrus  2019
# 5   Sucker \nWe go together\nBetter than birds of ...              NaN  2019
# 11  Sunflower \nAyy, ayy, ayy, ayy Ooh\nOoh, ooh, ...              NaN  2019
# 16  Without Me \nFound you when your heart was bro...              NaN  2019
# 22  7 rings \nYeah, breakfast at Tiffany's and bot...              NaN  2019
#
#     Month
# 0       7
# 5       7
# 11      7
# 16      7
# 22      7

# %%
#Checking out the top number of weeks a song hit number one. 

billboard_number_one[billboard_number_one['Weekly.rank']==1.0].groupby('Name')[['Weekly.rank']].sum().sort_values(by=['Weekly.rank'], ascending=False)


#important to note that the longest running time in the number one spot is 16 weeks.
# Out:
#                     Weekly.rank
# Name
# Despacito                    16
# We Belong Together           14
# I Gotta Feeling              14
# Old Town Road                13
# Shape Of You                 12
# ...                         ...
# Not Afraid                    1
# Ms. Jackson                   1
# 3                             1
# Inside Your Heaven            1
# You're Beautiful              1
#
# [230 rows x 1 columns]

# %%
#Breaking out the number of weeks each song spent at number one, with the year.

number_one_weeks=billboard_number_one[billboard_number_one['Weekly.rank']==1].groupby(['Name','Artists','Year'])[['Weekly.rank']].sum().sort_values(by='Weekly.rank', ascending=False)

number_one_weeks
# Out:
#                                                   Weekly.rank
# Name               Artists                  Year
# Despacito          Luis Fonsi, Daddy Yankee 2017           16
# I Gotta Feeling    The Black Eyed Peas      2009           14
# We Belong Together Mariah Carey             2005           14
# Old Town Road      Lil Nas,                 2019           13
# Boom Boom Pow      The Black Eyed Peas      2009           12
# ...                                                       ...
# Smooth             Santana                  2000            1
# Give Me Everything Pitbull                  2011            1
# Slow Jamz          Twista                   2004            1
# Havana             Camila Cabello           2018            1
# You're Beautiful   James Blunt              2006            1
#
# [249 rows x 1 columns]

# %%
#Average number of weeks each song spent at number one broken down by year to evaluate any shifts over time.

number_one_weeks.groupby(['Year']).agg(avg_weeks_one=('Weekly.rank',np.mean))
# Out:
#       avg_weeks_one
# Year
# 1999       4.000000
# 2000       2.562500
# 2001       3.384615
# 2002       5.888889
# 2003       4.333333
# 2004       4.000000
# 2005       6.500000
# 2006       2.736842
# 2007       3.000000
# 2008       3.769231
# 2009       3.785714
# 2010       3.062500
# 2011       3.750000
# 2012       4.083333
# 2013       4.727273
# 2014       5.444444
# 2015       4.571429
# 2016       4.818182
# 2017       4.333333
# 2018       4.333333
# 2019       3.857143

# %%
#number_one_songs['Weeks.on.chart']=billboard_number_one[(billboard_number_one['Artists','Name']==number_one_songs['Arists','Name'])& (billboard_number_one['Weeks.on.chart'].max())]

# %%
billboard_number_one.describe()
# Out:
#          Unnamed: 0  Weekly.rank  Peak.position  Weeks.on.chart         Year  \
# count   5566.000000  5566.000000         5566.0     5566.000000  5566.000000
# mean   45158.231405    16.175350            1.0       21.319978  2009.833273
# std    27345.091262    16.124465            0.0       12.589626     5.652648
# min        1.000000     1.000000            1.0        0.000000  1999.000000
# 25%    22131.750000     2.000000            1.0       12.000000  2006.000000
# 50%    44358.500000    10.000000            1.0       21.000000  2010.000000
# 75%    65048.250000    27.000000            1.0       29.000000  2015.000000
# max    97172.000000   100.000000            1.0       65.000000  2019.000000
#
#              Month
# count  5566.000000
# mean      6.377111
# std       3.419868
# min       1.000000
# 25%       3.000000
# 50%       6.000000
# 75%       9.000000
# max      12.000000

# %%
billboard_number_one['Name'].nunique()
# Out:
# 245

# %%
number_one_total_weeks=billboard_number_one.groupby(['Name','Artists']).agg(total_weeks_on_chart=('Weeks.on.chart','max'), debut_year=('Year','min'))

number_one_total_weeks.sort_values(by='total_weeks_on_chart', ascending=False, inplace=True)

number_one_total_weeks
# Out:
#                                                total_weeks_on_chart  \
# Name                         Artists
# Rolling In The Deep          Adele                             65.0
# All Of Me                    John Legend                       59.0
# Shape Of You                 Ed Sheeran                        59.0
# Somebody That I Used To Know Gotye                             59.0
# Smooth                       Santana                           58.0
# ...                                                             ...
# This Is The Night            Clay Aiken                        16.0
# Inside Your Heaven           Carrie Underwood                  12.0
# I Believe                    Fantasia                          10.0
# Old Town Road                Lil Nas,                           9.0
# Do I Make You Proud          Taylor Hicks                       8.0
#
#                                                debut_year
# Name                         Artists
# Rolling In The Deep          Adele                   2011
# All Of Me                    John Legend             2014
# Shape Of You                 Ed Sheeran              2017
# Somebody That I Used To Know Gotye                   2012
# Smooth                       Santana                 1999
# ...                                                   ...
# This Is The Night            Clay Aiken              2003
# Inside Your Heaven           Carrie Underwood        2005
# I Believe                    Fantasia                2004
# Old Town Road                Lil Nas,                2019
# Do I Make You Proud          Taylor Hicks            2006
#
# [245 rows x 2 columns]

# %%
#average total number of weeks a song that hits number one stays on the chart

number_one_avg_weeks=number_one_total_weeks.groupby('debut_year').agg(avg_weeks_top_songs=('total_weeks_on_chart',np.mean))

number_one_avg_weeks.reset_index(inplace=True)

number_one_avg_weeks
# Out:
#     debut_year  avg_weeks_top_songs
# 0         1999            27.900000
# 1         2000            31.200000
# 2         2001            28.538462
# 3         2002            26.285714
# 4         2003            26.363636
# 5         2004            30.000000
# 6         2005            29.571429
# 7         2006            27.888889
# 8         2007            29.875000
# 9         2008            31.153846
# 10        2009            33.538462
# 11        2010            29.066667
# 12        2011            35.545455
# 13        2012            33.866667
# 14        2013            35.363636
# 15        2014            44.555556
# 16        2015            37.166667
# 17        2016            35.846154
# 18        2017            37.230769
# 19        2018            36.454545
# 20        2019            27.000000

# %%
#all_total_weeks=billboard_df.groupby(['Name','Artists','Peak.position']).agg(total_weeks_on_chart=('Weeks.on.chart','max'), debut_year=('Year','min'),)

all_total_weeks=billboard_df.groupby(['Name','Artists']).agg(chart_debut_year=('Year','min'), total_weeks_on_chart=('Weeks.on.chart','max'), top_position=('Peak.position','min'))

all_total_weeks=all_total_weeks.sort_values(by='total_weeks_on_chart', ascending=False)

all_total_weeks
# Out:
#                                      chart_debut_year  total_weeks_on_chart  \
# Name                Artists
# Radioactive         Imagine Dragons              2012                  87.0
# Sail                AWOLNATION                   2011                  79.0
# I'm Yours           Jason Mraz                   2008                  76.0
# Counting Stars      OneRepublic                  2013                  68.0
# Rolling In The Deep Adele                        2010                  65.0
# ...                                               ...                   ...
# Yuck!               2 Chainz                     2012                   NaN
# Zoom                Future                       2017                   NaN
# fuck Him He's A DJ  Ke$ha                        2011                   NaN
# fuck That Check Up  Meek Mill                    2017                   NaN
# fuck Today          Lil Wayne                    2010                   NaN
#
#                                      top_position
# Name                Artists
# Radioactive         Imagine Dragons           3.0
# Sail                AWOLNATION               17.0
# I'm Yours           Jason Mraz                6.0
# Counting Stars      OneRepublic               2.0
# Rolling In The Deep Adele                     1.0
# ...                                           ...
# Yuck!               2 Chainz                  NaN
# Zoom                Future                    NaN
# fuck Him He's A DJ  Ke$ha                     NaN
# fuck That Check Up  Meek Mill                 NaN
# fuck Today          Lil Wayne                 NaN
#
# [7213 rows x 3 columns]

# %%
#Taking a look at the average number of total weeks and the average peak position a song hits by year
# 

avg_all_songs=all_total_weeks.groupby('chart_debut_year').agg(avg_peak_pos=('top_position', np.mean),avg_weeks_all_songs=('total_weeks_on_chart',np.mean))

avg_all_songs.reset_index(inplace=True)

avg_all_songs=avg_all_songs.join(number_one_avg_weeks['avg_weeks_top_songs'])

avg_all_songs
# Out:
#     chart_debut_year  avg_peak_pos  avg_weeks_all_songs  avg_weeks_top_songs
# 0               1999     34.877934            19.103286            27.900000
# 1               2000     42.270463            17.320285            31.200000
# 2               2001     39.206226            18.560311            28.538462
# 3               2002     41.695341            17.523297            26.285714
# 4               2003     42.234043            17.386525            26.363636
# 5               2004     41.454874            17.393502            30.000000
# 6               2005     43.222973            16.797297            29.571429
# 7               2006     42.240132            15.822368            27.888889
# 8               2007     39.804965            16.670213            29.875000
# 9               2008     41.009740            16.327922            31.153846
# 10              2009     41.654206            15.482866            33.538462
# 11              2010     37.686207            16.386207            29.066667
# 12              2011     41.684932            16.044521            35.545455
# 13              2012     41.480769            18.803846            33.866667
# 14              2013     42.591912            16.900735            35.363636
# 15              2014     41.108696            17.728261            44.555556
# 16              2015     45.856643            16.248252            37.166667
# 17              2016     40.784810            16.170886            35.846154
# 18              2017     43.056604            15.588050            37.230769
# 19              2018     37.524064            13.109626            36.454545
# 20              2019     46.676647             8.898204            27.000000

# %%
songs_count_year=all_total_weeks['chart_debut_year'].value_counts().to_frame().reset_index()


songs_count_year=songs_count_year.rename(columns={'index':'year', 'chart_debut_year':'song_count'}).sort_values(by='year')

songs_count_year=songs_count_year.reset_index().drop(columns='index', axis=1)

songs_count_year
# Out:
#     year  song_count
# 0   1999         214
# 1   2000         284
# 2   2001         257
# 3   2002         280
# 4   2003         284
# 5   2004         280
# 6   2005         314
# 7   2006         338
# 8   2007         314
# 9   2008         367
# 10  2009         404
# 11  2010         434
# 12  2011         442
# 13  2012         330
# 14  2013         342
# 15  2014         327
# 16  2015         361
# 17  2016         387
# 18  2017         439
# 19  2018         567
# 20  2019         248

# %%
#avg_all_songs=avg_all_songs.join(songs_count_year['song_count'])


#avg_all_songs=avg_all_songs.set_index('chart_debut_year').join(songs_count_year.set_index('year'), on='chart_debut_year', lsuffix='_left', rsuffix='_right',how='left')

avg_all_songs=avg_all_songs.set_index('chart_debut_year').join(songs_count_year.set_index('year'), on='chart_debut_year',how='left')

#avg_all_songs.drop(columns='song_count_right').rename(columns={'song_count_left':'total_songs'})

# %%
avg_all_songs
# Out:
#                   avg_peak_pos  avg_weeks_all_songs  avg_weeks_top_songs  \
# chart_debut_year
# 1999                 34.877934            19.103286            27.900000
# 2000                 42.270463            17.320285            31.200000
# 2001                 39.206226            18.560311            28.538462
# 2002                 41.695341            17.523297            26.285714
# 2003                 42.234043            17.386525            26.363636
# 2004                 41.454874            17.393502            30.000000
# 2005                 43.222973            16.797297            29.571429
# 2006                 42.240132            15.822368            27.888889
# 2007                 39.804965            16.670213            29.875000
# 2008                 41.009740            16.327922            31.153846
# 2009                 41.654206            15.482866            33.538462
# 2010                 37.686207            16.386207            29.066667
# 2011                 41.684932            16.044521            35.545455
# 2012                 41.480769            18.803846            33.866667
# 2013                 42.591912            16.900735            35.363636
# 2014                 41.108696            17.728261            44.555556
# 2015                 45.856643            16.248252            37.166667
# 2016                 40.784810            16.170886            35.846154
# 2017                 43.056604            15.588050            37.230769
# 2018                 37.524064            13.109626            36.454545
# 2019                 46.676647             8.898204            27.000000
#
#                   song_count
# chart_debut_year
# 1999                     214
# 2000                     284
# 2001                     257
# 2002                     280
# 2003                     284
# 2004                     280
# 2005                     314
# 2006                     338
# 2007                     314
# 2008                     367
# 2009                     404
# 2010                     434
# 2011                     442
# 2012                     330
# 2013                     342
# 2014                     327
# 2015                     361
# 2016                     387
# 2017                     439
# 2018                     567
# 2019                     248

# %%
#weeks_to_peak=billboard_df.groupby(['Name','Artists','Weekly.position']).agg(first_week_peak=(''))

# %%
weekly_rank_test=billboard_number_one[(billboard_number_one['Weeks.on.chart']==0)]

weekly_rank_test['Weekly.rank'].value_counts()

#I'm wondering here if my billboard_number_one dataframe I created is giving me accurate data or not. I doubt 
# that every song that hit number one started on the charts at number one... so I'm missing something here
# Out:
# 1    84
# Name: Weekly.rank, dtype: int64

# %%
test=billboard_df[(billboard_df['Weeks.on.chart']==1)]

test['Peak.position'].value_counts()


# I think i've found a significant error in this dataset that i'm having a hard time ironing out. 
# for some reason, any record where Weeks.on.chart == 1 or 0, the peak position is 1. Which doesn't make sense.
# Out:
# 1.0    116
# Name: Peak.position, dtype: int64

# %%
weekly_rank_test.head()
# Out:
#       Unnamed: 0        Artists            Name  Weekly.rank  Peak.position  \
# 691          692       Lil Nas,   Old Town Road            1            1.0
# 1284        1285  Ariana Grande         7 Rings            1            1.0
# 3634        3635       Maroon 5  Girls Like You            1            1.0
# 4117        4118          Drake  In My Feelings            1            1.0
# 5272        5273          Drake   Nice For What            1            1.0
#
#       Weeks.on.chart       Week       Date  \
# 691              0.0 2019-05-18   5-Apr-19
# 1284             0.0 2019-04-06  18-Jan-19
# 3634             0.0 2018-10-20  30-May-18
# 4117             0.0 2018-09-15  29-Jun-18
# 5272             0.0 2018-06-23   6-Apr-18
#
#                                                   Genre  \
# 691   Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 1284                                Memes,Trap,R&;B,Pop
# 3634                  Pop-Rock,East Coast,Remix,Rap,Pop
# 4117                    Bounce,Pop,Trap,Canada,R&;B,Rap
# 5272                             Bounce,Rap,Canada,R&;B
#
#                                         Writing.Credits  \
# 691   Jozzy, Atticus ross, Trent reznor, Billy ray c...
# 1284  Ariana grande, Richard rodgers, Tbhits, Njomza...
# 3634  Cardi b, Gian stone, Cirkut, Starrah, Adam lev...
# 4117  Phil triggaman price, Orville bugs can can hal...
# 5272  Phil triggaman price, Orville bugs can can hal...
#
#                                                  Lyrics         Features  \
# 691   Old Town Road Remix \nOh, oh-oh\nOh\nYeah, I'm...  Billy Ray Cyrus
# 1284  7 rings \nYeah, breakfast at Tiffany's and bot...              NaN
# 3634  Girls Like You Remix \nSpent 24 hours\nI need ...          Cardi B
# 4117  In My Feelings \nTrap, TrapMoneyBenny\nThis sh...              NaN
# 5272  Nice For What \nI wanna know who mothafucking ...              NaN
#
#       Year  Month
# 691   2019      5
# 1284  2019      4
# 3634  2018     10
# 4117  2018      9
# 5272  2018      6

# %%
#taking a look at how comprehesive the data is. There should be a row for every single week a song appears on the 
# charts. These are all the songs that hit #1... It is unlikely that any of the should appear on the top 100 list
# for just one single week. It is clear that this data set is missing records on a quite a few fronts. 

number_one_songs=billboard_number_one[['Artists','Name']].value_counts().reset_index(name='count')

number_one_songs
# Out:
#                  Artists                     Name  count
# 0             Ed Sheeran             Shape Of You     58
# 1    The Black Eyed Peas          I Gotta Feeling     54
# 2      Justin Timberlake  Can't Stop The Feeling!     52
# 3       The Chainsmokers                   Closer     50
# 4           Taylor Swift             Shake It Off     50
# ..                   ...                      ...    ...
# 240                Wham!         Careless Whisper      1
# 241      Whitney Houston          How Will I Know      1
# 242                 Cher                  Believe      1
# 243      Michael Jackson              Billie Jean      1
# 244             Bon Jovi       Livin' On A Prayer      1
#
# [245 rows x 3 columns]

# %%
number_one_songs[number_one_songs['count']==1]
#there are six songs that appear only one time on the chart but hit number one... will need to investigate this.
# Out:
#              Artists                Name  count
# 239   George Michael               Faith      1
# 240            Wham!    Careless Whisper      1
# 241  Whitney Houston     How Will I Know      1
# 242             Cher             Believe      1
# 243  Michael Jackson         Billie Jean      1
# 244         Bon Jovi  Livin' On A Prayer      1

# %%
#Taking the songs above into a separate little dataframe to see if there are any patterns as to why just 
# these songs would be missing the rest of their records. Pulling from the original billboard_df dataframe
# to ensure there were no issues in how I selected records for the reduced billboard_number_one songs etc. 



data=[billboard_df[(billboard_df['Name']=='Faith')],billboard_df[(billboard_df['Name']=='Careless Whisper')& (billboard_df['Artists']=='Wham!')],billboard_df[(billboard_df['Name']=='How Will I Know')],billboard_df[(billboard_df['Name']=='Believe')& (billboard_df['Artists']=='Cher')], billboard_df[(billboard_df['Name']=='Billie Jean')], billboard_df[(billboard_df['Name']=="Livin' On A Prayer")]]

df2=pd.concat(data)

df2
# Out:
#        Unnamed: 0          Artists                Name  Weekly.rank  \
# 12671       12672   George Michael               Faith           47
# 12658       12659            Wham!    Careless Whisper           33
# 35439       35440        Glee Cast     How Will I Know           65
# 36348       36349  Whitney Houston     How Will I Know           49
# 97171       97172             Cher             Believe           41
# 25309       25310  Michael Jackson         Billie Jean           14
# 27792       27793         Bon Jovi  Livin' On A Prayer           25
#
#        Peak.position  Weeks.on.chart       Week       Date  \
# 12671            1.0            21.0 2017-01-14        NaN
# 12658            1.0            22.0 2017-01-14        NaN
# 35439            NaN             NaN 2012-05-11  24-Apr-12
# 36348            1.0            24.0 2012-03-02        NaN
# 97171            1.0            31.0 1999-07-12        NaN
# 25309            1.0            25.0 2014-06-06        NaN
# 27792            1.0            22.0 2013-11-29        NaN
#
#                                                 Genre  \
# 12671          Blue-Eyed Soul,Pop,Soul,R&;B,Funk,Rock
# 12658                          Eighties,R&;B,Pop,Jazz
# 35439                                             Pop
# 36348                                  Dance-Pop,R&;B
# 97171                                       Dance,Pop
# 25309  Eighties,Funk,Synth-Pop,Soul,Soul Pop,R&;B,Pop
# 27792                        Hard Rock,Glam Rock,Rock
#
#                                          Writing.Credits  \
# 12671                                     George michael
# 12658                    Andrew ridgeley, George michael
# 35439  Narada michael walden, Shannon rubicam, George...
# 36348  Narada michael walden, Shannon rubicam, George...
# 97171             Steve torch, Paul barry, Brian higgins
# 25309                                    Michael jackson
# 27792        Desmond child, Richie sambora, Jon bon jovi
#
#                                                   Lyrics        Features  \
# 12671  Faith\nFaith \nWell I guess it would be nice i...             NaN
# 12658  Careless Whisper \nTime can never mend\nThe ca...  George Michael
# 35439  How Will I Know? \nMercedes:\nThere's a boy I ...             NaN
# 36348  How Will I Know \nThere's a boy I know, he's t...             NaN
# 97171  Believe \nAfter love, after love\nAfter love, ...             NaN
# 25309  Billie Jean \nShe was more like a beauty queen...             NaN
# 27792  Living on a Prayer \nOnce upon a time, not so ...             NaN
#
#        Year  Month
# 12671  2017      1
# 12658  2017      1
# 35439  2012      5
# 36348  2012      3
# 97171  1999      7
# 25309  2014      6
# 27792  2013     11

# %%
#number_one_year=billboard_number_one[billboard_number_one['Weekly.rank']==1].groupby

#number_one_year.head()

# %%
number_one_nulldate=billboard_number_one[billboard_number_one['Date'].isnull()]

number_one_nulldate['Year'].value_counts()
# Out:
# 2000    156
# 1999    120
# 2004     30
# 2001     25
# 2003     16
# 2012      8
# 2016      6
# 2005      3
# 2017      2
# 2014      1
# 2013      1
# Name: Year, dtype: int64

# %%
number_one_nulldate['Name'].nunique()

#There are 32 total songs with a null value for the date... May be records that I end up dropping.
# Out:
# 32

# %%
artist_df.head()
# Out:
#    X          Artist  Followers  \
# 0  0      Ed Sheeran   52698756
# 1  1   Justin Bieber   30711450
# 2  2  Jonas Brothers    3069527
# 3  3           Drake   41420478
# 4  4     Chris Brown    9676862
#
#                                               Genres  NumAlbums  \
# 0                                         pop,uk pop          8
# 1           canadian pop,dance pop,pop,post-teen pop         10
# 2               boy band,dance pop,pop,post-teen pop         10
# 3  canadian hip hop,canadian pop,hip hop,pop rap,...         11
# 4                      dance pop,pop,pop rap,r&b,rap          6
#
#    YearFirstAlbum Gender Group.Solo
# 0            2011      M       Solo
# 1            2009      M       Solo
# 2            2006      M      Group
# 3            2010      M       Solo
# 4            2005      M       Solo

# %%
artist_df.info()

# Good to see there are very few artists that are missing Genre information. 
# I don't see Gender and Group.Solo being areas I would heavily use. Will keep rows missing that data in case
# I change my mind.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   X               1035 non-null   int64
#  1   Artist          1035 non-null   object
#  2   Followers       1035 non-null   int64
#  3   Genres          1017 non-null   object
#  4   NumAlbums       1035 non-null   int64
#  5   YearFirstAlbum  1035 non-null   int64
#  6   Gender          951 non-null    object
#  7   Group.Solo      1019 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 64.8+ KB

# %%
artist_df.duplicated().value_counts()

#no duplicated rows here
# Out:
# False    1035
# dtype: int64

# %%
artist_df[artist_df['Genres'].isnull()]

#will have to see if artists missing genres here have genres listed in the billboard_df dataframe.
# Out:
#          X              Artist  Followers Genres  NumAlbums  YearFirstAlbum  \
# 56      56         Bobby Helms      10470    NaN         21            1957
# 254    254            R. Kelly    1966122    NaN         18            1992
# 394    394                Dcup       6787    NaN          6            2010
# 407    407  Cali Swag District      70364    NaN          4            2011
# 412    412        Chris Willis      11466    NaN          7            2006
# 542    542           Yael Naim     101038    NaN          5            2007
# 568    568       Elliott Yamin      73177    NaN          6            2007
# 572    572    Down A.K.A. Kilo        775    NaN          5            1998
# 621    621              Ca$his      37226    NaN          8            2011
# 623    623      Lady Sovereign      35769    NaN          4            2005
# 637    637         Nick Lachey     104032    NaN          3            2003
# 755    755     Los Lonely Boys      46830    NaN         11            2004
# 788    788        Lostprophets     119047    NaN          6            2001
# 856    856             Benzino       4593    NaN          4            2001
# 965    965               Ideal       4543    NaN          4            1999
# 984    984             Sonique      24629    NaN          4            2000
# 1029  1029        Terry Dexter        790    NaN          3            1999
# 1031  1031       Jordan Knight      47229    NaN          4            1999
#
#      Gender Group.Solo
# 56        M       Solo
# 254       M       Solo
# 394       M       Solo
# 407       M      Group
# 412       M       Solo
# 542       F       Solo
# 568       M       Solo
# 572       M       Solo
# 621       M       Solo
# 623       F       Solo
# 637       M       Solo
# 755       M      Group
# 788       M      Group
# 856       M       Solo
# 965     NaN        NaN
# 984       F       Solo
# 1029      F       Solo
# 1031      M       Solo

# %%
artist_df.NumAlbums.mean()

#good to see the average number of albums I'm working with.
# Out:
# 11.329468599033817

# %%
genres=artist_df['Genres'].apply(pd.Series).reset_index().melt(id_vars='index').dropna()[['index', 'value']].set_index('index')

genres.rename(columns={'value':'Genres'}, inplace=True)

genres

#Here I am splitting the Genres out to a separate table in an attempt to isolate and consolidate the different
# genre options for a more clear analysis
# Out:
#                                                   Genres
# index
# 0                                             pop,uk pop
# 1               canadian pop,dance pop,pop,post-teen pop
# 2                   boy band,dance pop,pop,post-teen pop
# 3      canadian hip hop,canadian pop,hip hop,pop rap,...
# 4                          dance pop,pop,pop rap,r&b,rap
# ...                                                  ...
# 1028   argentine rock,cantautor,folklore argentino,nu...
# 1030   country,country rock,nashville sound,outlaw co...
# 1032           contemporary country,country,country dawn
# 1033                                            rap rock
# 1034   alternative metal,alternative rock,pop rock,po...
#
# [1017 rows x 1 columns]

# %%
genres['Genres']=genres['Genres'].str.split(',')

genres

#genres_full=genres['Genres'].apply(pd.Series).reset_index().melt(id_vars='index').dropna()[['index', 'value']].set_index('index')

#genres_full
# Out:
#                                                   Genres
# index
# 0                                          [pop, uk pop]
# 1          [canadian pop, dance pop, pop, post-teen pop]
# 2              [boy band, dance pop, pop, post-teen pop]
# 3      [canadian hip hop, canadian pop, hip hop, pop ...
# 4                    [dance pop, pop, pop rap, r&b, rap]
# ...                                                  ...
# 1028   [argentine rock, cantautor, folklore argentino...
# 1030   [country, country rock, nashville sound, outla...
# 1032       [contemporary country, country, country dawn]
# 1033                                          [rap rock]
# 1034   [alternative metal, alternative rock, pop rock...
#
# [1017 rows x 1 columns]

# %%
artist_genre=artist_df.copy()

artist_genre['Genres_list']=artist_genre['Genres'].str.split(',')

artist_genre


#Converting the genre column into a list for ease of breaking these out into individual rows.
# Out:
#          X           Artist  Followers  \
# 0        0       Ed Sheeran   52698756
# 1        1    Justin Bieber   30711450
# 2        2   Jonas Brothers    3069527
# 3        3            Drake   41420478
# 4        4      Chris Brown    9676862
# ...    ...              ...        ...
# 1030  1030    Dwight Yoakam     284597
# 1031  1031    Jordan Knight      47229
# 1032  1032      Lila McCann      42444
# 1033  1033         Everlast     200550
# 1034  1034  Collective Soul     525701
#
#                                                  Genres  NumAlbums  \
# 0                                            pop,uk pop          8
# 1              canadian pop,dance pop,pop,post-teen pop         10
# 2                  boy band,dance pop,pop,post-teen pop         10
# 3     canadian hip hop,canadian pop,hip hop,pop rap,...         11
# 4                         dance pop,pop,pop rap,r&b,rap          6
# ...                                                 ...        ...
# 1030  country,country rock,nashville sound,outlaw co...         25
# 1031                                                NaN          4
# 1032          contemporary country,country,country dawn          4
# 1033                                           rap rock         11
# 1034  alternative metal,alternative rock,pop rock,po...         12
#
#       YearFirstAlbum Gender Group.Solo  \
# 0               2011      M       Solo
# 1               2009      M       Solo
# 2               2006      M      Group
# 3               2010      M       Solo
# 4               2005      M       Solo
# ...              ...    ...        ...
# 1030            1985      M       Solo
# 1031            1999      M       Solo
# 1032            1997      F       Solo
# 1033            1990      M       Solo
# 1034            1994      M      Group
#
#                                             Genres_list
# 0                                         [pop, uk pop]
# 1         [canadian pop, dance pop, pop, post-teen pop]
# 2             [boy band, dance pop, pop, post-teen pop]
# 3     [canadian hip hop, canadian pop, hip hop, pop ...
# 4                   [dance pop, pop, pop rap, r&b, rap]
# ...                                                 ...
# 1030  [country, country rock, nashville sound, outla...
# 1031                                                NaN
# 1032      [contemporary country, country, country dawn]
# 1033                                         [rap rock]
# 1034  [alternative metal, alternative rock, pop rock...
#
# [1035 rows x 9 columns]

# %%
#split lists of genres out into a separate row for each each genre associated with each artist artist. 

genres_test=artist_genre['Genres_list'].apply(pd.Series).reset_index().melt(id_vars='index').dropna()[['index', 'value']].set_index('index')

genres_test
# Out:
#                   value
# index
# 0                   pop
# 1          canadian pop
# 2              boy band
# 3      canadian hip hop
# 4             dance pop
# ...                 ...
# 266      permanent wave
# 692           soft rock
# 961          yacht rock
# 266        quebec indie
# 266                rock
#
# [5419 rows x 1 columns]

# %%
# Merge the split out genres with the artists they align with. Each artist will have a separate line for each 
# genre associated with them.

artist_genre_solo=pd.merge(artist_genre, genres_test, left_index=True, right_index=True)
artist_genre_solo.rename(columns={'value':'solo_genre'}, inplace=True)
artist_genre_solo

# I've kept the original Genres column, and genres_list column for potential use down the road.
# Out:
#          X           Artist  Followers  \
# 0        0       Ed Sheeran   52698756
# 0        0       Ed Sheeran   52698756
# 1        1    Justin Bieber   30711450
# 1        1    Justin Bieber   30711450
# 1        1    Justin Bieber   30711450
# ...    ...              ...        ...
# 1034  1034  Collective Soul     525701
# 1034  1034  Collective Soul     525701
# 1034  1034  Collective Soul     525701
# 1034  1034  Collective Soul     525701
# 1034  1034  Collective Soul     525701
#
#                                                  Genres  NumAlbums  \
# 0                                            pop,uk pop          8
# 0                                            pop,uk pop          8
# 1              canadian pop,dance pop,pop,post-teen pop         10
# 1              canadian pop,dance pop,pop,post-teen pop         10
# 1              canadian pop,dance pop,pop,post-teen pop         10
# ...                                                 ...        ...
# 1034  alternative metal,alternative rock,pop rock,po...         12
# 1034  alternative metal,alternative rock,pop rock,po...         12
# 1034  alternative metal,alternative rock,pop rock,po...         12
# 1034  alternative metal,alternative rock,pop rock,po...         12
# 1034  alternative metal,alternative rock,pop rock,po...         12
#
#       YearFirstAlbum Gender Group.Solo  \
# 0               2011      M       Solo
# 0               2011      M       Solo
# 1               2009      M       Solo
# 1               2009      M       Solo
# 1               2009      M       Solo
# ...              ...    ...        ...
# 1034            1994      M      Group
# 1034            1994      M      Group
# 1034            1994      M      Group
# 1034            1994      M      Group
# 1034            1994      M      Group
#
#                                             Genres_list         solo_genre
# 0                                         [pop, uk pop]                pop
# 0                                         [pop, uk pop]             uk pop
# 1         [canadian pop, dance pop, pop, post-teen pop]       canadian pop
# 1         [canadian pop, dance pop, pop, post-teen pop]          dance pop
# 1         [canadian pop, dance pop, pop, post-teen pop]                pop
# ...                                                 ...                ...
# 1034  [alternative metal, alternative rock, pop rock...  alternative metal
# 1034  [alternative metal, alternative rock, pop rock...   alternative rock
# 1034  [alternative metal, alternative rock, pop rock...           pop rock
# 1034  [alternative metal, alternative rock, pop rock...        post-grunge
# 1034  [alternative metal, alternative rock, pop rock...               rock
#
# [5419 rows x 10 columns]

# %%
#creating condensed categories 


#country
artist_genre_solo['solo_genre']= ['country' if 'country' in x else x for x in artist_genre_solo['solo_genre']]


#pop
artist_genre_solo['solo_genre']= ['pop' if 'pop' in x else x for x in artist_genre_solo['solo_genre']]


#rock
artist_genre_solo['solo_genre']= ['rock' if 'rock' in x else x for x in artist_genre_solo['solo_genre']]


#rap
artist_genre_solo['solo_genre']= ['rap' if 'rap' in x else x for x in artist_genre_solo['solo_genre']]


#dance/electronic/house
artist_genre_solo['solo_genre']= ['dance/electronic/house' if 'dance' in x  or 'electronic' in x or 'house' in x or 'dubstep' in x else x for x in artist_genre_solo['solo_genre']]


#alternative/indie
artist_genre_solo['solo_genre']= ['alternative/indie' if 'alternative' in x or 'indie' in x else x for x in artist_genre_solo['solo_genre']]


#hip hop
artist_genre_solo['solo_genre']= ['hip hop' if 'hip hop' in x or 'hiphop' in x else x for x in artist_genre_solo['solo_genre']]


#R&B
artist_genre_solo['solo_genre']= ['r&b' if 'r&b' in x or 'r & b' in x else x for x in artist_genre_solo['solo_genre']]


#Others
#artist_genre_solo['solo_genre']= ['other' if 'rap' not in x or 'r&b' not in x or 'hip hop' not in x or 'alternative' not in x or 'dance' not in x or 'rock' not in x or 'pop' not in x else x for x in artist_genre_solo['solo_genre']]


artist_genre_solo['solo_genre'].value_counts()
# Out:
# pop                1493
# country             572
# rock                521
# rap                 519
# hip hop             492
#                    ...
# jam band              1
# french shoegaze       1
# drum and bass         1
# cedm                  1
# trova                 1
# Name: solo_genre, Length: 209, dtype: int64

# %%
#lump the remaining one off genres into an 'others' category

artist_genre_solo['solo_genre']=np.where((artist_genre_solo['solo_genre'] != 'pop') & (artist_genre_solo['solo_genre'] != 'country') & (artist_genre_solo['solo_genre'] != 'rock') & (artist_genre_solo['solo_genre'] != 'rap') & (artist_genre_solo['solo_genre'] != 'dance/electronic/house') & (artist_genre_solo['solo_genre'] != 'alternative/indie') & (artist_genre_solo['solo_genre'] != 'hip hop') & (artist_genre_solo['solo_genre'] != 'r&b'), 'others', artist_genre_solo['solo_genre'])

artist_genre_solo['solo_genre'].value_counts()
# Out:
# pop                       1493
# others                    1391
# country                    572
# rock                       521
# rap                        519
# hip hop                    492
# alternative/indie          175
# r&b                        143
# dance/electronic/house     113
# Name: solo_genre, dtype: int64

# %%
artist_genre_solo.count()
# Out:
# X                 5419
# Artist            5419
# Followers         5419
# Genres            5419
# NumAlbums         5419
# YearFirstAlbum    5419
# Gender            4947
# Group.Solo        5334
# Genres_list       5419
# solo_genre        5419
# dtype: int64

# %%
#Dropping the Genres_list column as it is a 'unhashable type' and prevents me from dropping the dulicates
artist_genre_solo.drop(columns='Genres_list', inplace=True)

artist_genre_solo.duplicated().value_counts()
# Out:
# True     2937
# False    2482
# dtype: int64

# %%
#Dropping duplicated rows to eliminate redunancies in genre categorization. 

artist_genre_solo=artist_genre_solo.drop_duplicates()

artist_genre_solo.duplicated().value_counts()

#I wanted to keep information on artists that fall into multiple major genre categories for my analysis.
# Out:
# False    2482
# dtype: int64

# %%
grammy_songs_df.head()
# Out:
#    Unnamed: 0  X                     GrammyAward  GrammyYear  \
# 0           1  0              Record Of The Year        2018
# 1           2  1                Song Of The Year        2018
# 2           3  2       Best Pop Solo Performance        2018
# 3           4  3  Best Pop Duo/Group Performance        2018
# 4           5  4            Best Dance Recording        2018
#
#                     Genre                                       Name  \
# 0                 General                            this is America
# 1                 General                            this is America
# 2                     Pop  Joanne (where Do you Think You're Goin'?)
# 3                     Pop                                    Shallow
# 4  Dance/Electronic Music                                Electricity
#
#                                               Artist
# 0                                   Childish Gambino
# 1                                   Childish Gambino
# 2                                          Lady Gaga
# 3                         Lady Gaga & Bradley Cooper
# 4  Silk City & Dua Lipa Featuring Diplo & Mark Ro...

# %%
grammy_songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   428 non-null    int64
#  1   X            428 non-null    int64
#  2   GrammyAward  428 non-null    object
#  3   GrammyYear   428 non-null    int64
#  4   Genre        428 non-null    object
#  5   Name         428 non-null    object
#  6   Artist       417 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 23.5+ KB

# %%
grammy_songs_df[grammy_songs_df['Artist'].isnull()]

# I may be able to fill in the missing artist info here. Not sure I will need to.
# Out:
#      Unnamed: 0    X                         GrammyAward  GrammyYear  \
# 101         102  101                       Best R&B Song        2014
# 111         112  111            Best American Roots Song        2014
# 114         115  114                    Song Of The Year        2013
# 120         121  120                      Best Rock Song        2013
# 123         124  123                       Best R&B Song        2013
# 125         126  125                       Best Rap Song        2013
# 128         129  128                   Best Country Song        2013
# 130         131  130            Best American Roots Song        2013
# 131         132  131  Best Song Written For Visual Media        2013
# 148         149  148  Best Song Written For Visual Media        2012
# 335         336  335                       Best R&B Song        2003
#
#                     Genre                                  Name Artist
# 101                   R&B                         Drunk in Love    NaN
# 111  American Roots Music                a Feather's not a Bird    NaN
# 114               General                                Royals    NaN
# 120                  Rock                     Cut Me some Slack    NaN
# 123                   R&B                      Pusher Love Girl    NaN
# 125                   Rap                           Thrift Shop    NaN
# 128               Country                       Merry Go 'Round    NaN
# 130  American Roots Music                 Love Has Come for you    NaN
# 131   Composing/Arranging                               Skyfall    NaN
# 148   Composing/Arranging  Safe & Sound (from the Hunger Games)    NaN
# 335                   R&B                         Crazy in Love    NaN

# %%
grammy_songs_df['GrammyYear'].value_counts().rename_axis('years').reset_index(name='counts').sort_values(by='years')


#because there is incomplete data for 2019 in the billboard df and the grammy awards only go to 2018, I will
# restrict my data for certain evals to 1999-2018 only.
# Out:
#     years  counts
# 16   1999      20
# 12   2000      21
# 13   2001      21
# 3    2002      23
# 0    2003      25
# 5    2004      22
# 11   2005      22
# 10   2006      22
# 15   2007      21
# 14   2008      21
# 9    2009      22
# 8    2010      22
# 18   2011      17
# 19   2012      17
# 17   2013      19
# 7    2014      22
# 6    2015      22
# 2    2016      23
# 4    2017      23
# 1    2018      23

# %%
grammy_songs_df['Genre'].value_counts()
# Out:
# Rock                                   76
# R&B                                    76
# Pop                                    67
# Country                                60
# Rap                                    53
# General                                40
# Dance/Electronic Music                 17
# American Roots Music                   11
# Jazz                                   10
# Gospel/Contemporary Christian Music    10
# Composing/Arranging                     8
# Name: Genre, dtype: int64

# %%
grammy_songs_df['GrammyAward'].value_counts()
# Out:
# Record Of The Year                                    20
# Best Dance Recording                                  20
# Song Of The Year                                      20
# Best Rock Song                                        20
# Best Country Song                                     20
# Best R&B Song                                         19
# Best Metal Performance                                18
# Best Rap Song                                         16
# Best Rap Performance By A Duo Or Group                12
# Best Female Country Vocal Performance                 12
# Best Male Country Vocal Performance                   12
# Best Male Pop Vocal Performance                       12
# Best Female Pop Vocal Performance                     12
# Best Pop Collaboration With Vocals                    12
# Best Hard Rock Performance                            12
# Best Female R&B Vocal Performance                     12
# Best Male R&B Vocal Performance                       12
# Best Rap Solo Performance                             10
# Best Improvised Jazz Solo                             10
# Best Urban/Alternative Performance                     9
# Best Song Written For Visual Media                     8
# Best R&B Performance By A Duo Or Group With Vocals     8
# Best Rock Performance                                  8
# Best Pop Solo Performance                              8
# Best Country Duo/Group Performance                     8
# Best Country Solo Performance                          8
# Best Rock Performance By A Duo Or Group With Vocal     8
# Best Rap Performance                                   8
# Best Traditional R&B Performance                       8
# Best R&B Performance                                   8
# Best Pop Duo/Group Performance                         8
# Best Pop Performance By A Duo Or Group With Vocal      8
# Best American Roots Song                               6
# Best American Roots Performance                        5
# Best Contemporary Christian Music Performance/Song     5
# Best Gospel Performance/Song                           5
# Best Female Rock Vocal Performance                     5
# Best Male Rock Vocal Performance                       5
# Best Pop Performance By A Duo Or Group With Vocals     4
# Best Rap/Sung Performance                              3
# Best Female Rap Solo Performance                       2
# Best Male Rap Solo Performance                         2
# Name: GrammyAward, dtype: int64

# %%
grammy_songs_df[grammy_songs_df['GrammyAward']=='Record Of The Year']
# Out:
#      Unnamed: 0    X         GrammyAward  GrammyYear    Genre  \
# 0             1    0  Record Of The Year        2018  General
# 23           24   23  Record Of The Year        2017  General
# 46           47   46  Record Of The Year        2016  General
# 69           70   69  Record Of The Year        2015  General
# 91           92   91  Record Of The Year        2014  General
# 113         114  113  Record Of The Year        2013  General
# 132         133  132  Record Of The Year        2012  General
# 149         150  149  Record Of The Year        2011  General
# 166         167  166  Record Of The Year        2010  General
# 188         189  188  Record Of The Year        2009  General
# 210         211  210  Record Of The Year        2008  General
# 231         232  231  Record Of The Year        2007  General
# 252         253  252  Record Of The Year        2006  General
# 274         275  274  Record Of The Year        2005  General
# 296         297  296  Record Of The Year        2004  General
# 318         319  318  Record Of The Year        2003  General
# 343         344  343  Record Of The Year        2002  General
# 366         367  366  Record Of The Year        2001  General
# 387         388  387  Record Of The Year        2000  General
# 408         409  408  Record Of The Year        1999  General
#
#                                  Name  \
# 0                     this is America
# 23                          24k Magic
# 46                              Hello
# 69                        Uptown Funk
# 91   Stay with Me (Darkchild Version)
# 113                         Get Lucky
# 132      Somebody that i Used to Know
# 149               Rolling in the Deep
# 166                      Need you Now
# 188                      Use Somebody
# 210            Please Read the Letter
# 231                             Rehab
# 252            Not Ready to Make Nice
# 274        Boulevard of Broken Dreams
# 296                  Here We Go Again
# 318                            Clocks
# 343                    Don't Know Why
# 366                           Walk on
# 387                     Beautiful Day
# 408                            Smooth
#
#                                                 Artist
# 0                                     Childish Gambino
# 23                                          Bruno Mars
# 46                                               Adele
# 69                    Mark Ronson Featuring Bruno Mars
# 91                                           Sam Smith
# 113  Daft punk featuring Pharrell Williams & Nile R...
# 132                             Gotye Featuring Kimbra
# 149                                              Adele
# 166                                    Lady Antebellum
# 188                                      Kings of Leon
# 210                                      Alison Krauss
# 231                                      Amy Winehouse
# 252                                       Dixie Chicks
# 274                                          Green Day
# 296                                        Norah Jones
# 318                                           Coldplay
# 343                                        Norah Jones
# 366                                                 U2
# 387                                                 U2
# 408                       santana featuring Rob Thomas

# %%
#Checking to see how if the Artist category is going to cause issue. May focus on matching by the song name. 

grammy_songs_df.loc[grammy_songs_df['Artist'].str.contains('featuring', na=False, case=False)]
# Out:
#      Unnamed: 0    X                                        GrammyAward  \
# 4             5    4                               Best Dance Recording
# 8             9    8                               Best R&B Performance
# 9            10    9                   Best Traditional R&B Performance
# 18           19   18                       Best Gospel Performance/Song
# 19           20   19  Best Contemporary Christian Music Performance/...
# 35           36   35                          Best Rap/Sung Performance
# 50           51   50                               Best Dance Recording
# 57           58   57                               Best Rap Performance
# 61           62   61                 Best Country Duo/Group Performance
# 69           70   69                                 Record Of The Year
# 72           73   72                     Best Pop Duo/Group Performance
# 95           96   95                               Best Dance Recording
# 99          100   99                               Best R&B Performance
# 109         110  109  Best Contemporary Christian Music Performance/...
# 113         114  113                                 Record Of The Year
# 116         117  116                     Best Pop Duo/Group Performance
# 117         118  117                               Best Dance Recording
# 124         125  124                               Best Rap Performance
# 132         133  132                                 Record Of The Year
# 133         134  133                                   Song Of The Year
# 135         136  135                     Best Pop Duo/Group Performance
# 136         137  136                               Best Dance Recording
# 226         227  226             Best Rap Performance By A Duo Or Group
# 227         228  227                                      Best Rap Song
# 244         245  244                 Best Urban/Alternative Performance
# 247         248  247             Best Rap Performance By A Duo Or Group
# 248         249  248                                      Best Rap Song
# 269         270  269             Best Rap Performance By A Duo Or Group
# 270         271  270                                      Best Rap Song
# 279         280  279                 Best Pop Collaboration With Vocals
# 280         281  280                               Best Dance Recording
# 328         329  328                         Best Hard Rock Performance
# 359         360  359                                      Best R&B Song
# 362         363  362             Best Rap Performance By A Duo Or Group
# 404         405  404             Best Rap Performance By A Duo Or Group
# 408         409  408                                 Record Of The Year
# 409         410  409                                   Song Of The Year
# 413         414  413                 Best Pop Collaboration With Vocals
# 417         418  417  Best Rock Performance By A Duo Or Group With V...
# 424         425  424             Best Rap Performance By A Duo Or Group
#
#      GrammyYear                                Genre  \
# 4          2018               Dance/Electronic Music
# 8          2018                                  R&B
# 9          2018                                  R&B
# 18         2018  Gospel/Contemporary Christian Music
# 19         2018  Gospel/Contemporary Christian Music
# 35         2017                                  Rap
# 50         2016               Dance/Electronic Music
# 57         2016                                  Rap
# 61         2016                              Country
# 69         2015                              General
# 72         2015                                  Pop
# 95         2014               Dance/Electronic Music
# 99         2014                                  R&B
# 109        2014  Gospel/Contemporary Christian Music
# 113        2013                              General
# 116        2013                                  Pop
# 117        2013               Dance/Electronic Music
# 124        2013                                  Rap
# 132        2012                              General
# 133        2012                              General
# 135        2012                                  Pop
# 136        2012               Dance/Electronic Music
# 226        2008                                  Rap
# 227        2008                                  Rap
# 244        2007                                  R&B
# 247        2007                                  Rap
# 248        2007                                  Rap
# 269        2006                                  Rap
# 270        2006                                  Rap
# 279        2005                                  Pop
# 280        2005               Dance/Electronic Music
# 328        2003                                 Rock
# 359        2002                                  R&B
# 362        2002                                  Rap
# 404        2000                                  Rap
# 408        1999                              General
# 409        1999                              General
# 413        1999                                  Pop
# 417        1999                                 Rock
# 424        1999                                  Rap
#
#                                     Name  \
# 4                            Electricity
# 8                              Best Part
# 9                  How Deep is your Love
# 18                           Never Alone
# 19                               you Say
# 35                              Loyalty.
# 50                     Don't Let Me Down
# 57                            No Problem
# 61                                Jolene
# 69                           Uptown Funk
# 72                           Uptown Funk
# 95                             Rather be
# 99                         Drunk in Love
# 109                           Messengers
# 113                            Get Lucky
# 116                            Get Lucky
# 117                              Clarity
# 124                          Thrift Shop
# 132         Somebody that i Used to Know
# 133                         We are Young
# 135         Somebody that i Used to Know
# 136                            Bangarang
# 226                       Swagga Like Us
# 227                             Lollipop
# 244                          Daydreamin'
# 247                            Southside
# 248                            Good Life
# 269                                Ridin
# 270                          Money Maker
# 279                       Feel Good Inc.
# 280                            Galvanize
# 328                     Bring Me to Life
# 359  Love of My Life (an Ode to Hip Hop)
# 362                      The Whole World
# 404                     Forgot About Dre
# 408                               Smooth
# 409                               Smooth
# 413                               Smooth
# 417                   Put your Lights on
# 424                           you Got Me
#
#                                                 Artist
# 4    Silk City & Dua Lipa Featuring Diplo & Mark Ro...
# 8                        He.r. Featuring Daniel Caesar
# 9                            Pj Morton Featuring Yebba
# 18   Tori Kelly Featuring Kirk Franklin; Kirk Frank...
# 19   Lauren Daigle; Lauren Daigle, Jason Ingram & P...
# 35                    Kendrick Lamar Featuring Rihanna
# 50                     The Chainsmokers Featuring Daya
# 57    Chance the Rapper Featuring Lil Wayne & 2 Chainz
# 61                   Pentatonix Featuring Dolly Parton
# 69                    Mark Ronson Featuring Bruno Mars
# 72                    Mark Ronson Featuring Bruno Mars
# 95                  Clean Bandit Featuring Jess Glynne
# 99   Beyoncé & Jay Z, Artists (Beyoncé Featuring Ja...
# 109                Lecrae Featuring for King & Country
# 113  Daft punk featuring Pharrell Williams & Nile R...
# 116  Daft punk featuring Pharrell Williams & Nile R...
# 117                               Zedd Featuring Foxes
# 124             Macklemore & Ryan lewis featuring Wanz
# 132                             Gotye Featuring Kimbra
# 133                        Fun Featuring Janelle Monáe
# 135                             Gotye Featuring Kimbra
# 136                           skrillex featuring Sirah
# 226       Jay-z & Ti. Featuring Kanye West & Lil Wayne
# 227                   Lil Wayne Featuring Static Major
# 244                   Lupe Fiasco Featuring Jill Scott
# 247                        Common Featuring Kanye West
# 248                        Kanye West Featuring t-Pain
# 269              Chamillionaire Featuring Krayzie Bone
# 270                        Ludacris Featuring Pharrell
# 279                      Gorillaz Featuring De La Soul
# 280              The Chemical Brothers Featuring q-Tip
# 328                   Evanescence Featuring Paul Mccoy
# 359                       Erykah Badu Featuring Common
# 362                      Outkast Featuring Killer Mike
# 404                            Dr Dre Featuring Eminem
# 408                       santana featuring Rob Thomas
# 409                       Santana Featuring Rob Thomas
# 413                       santana featuring Rob Thomas
# 417                         santana featuring Everlast
# 424                    The roots featuring Erykah Badu

# %%
#billboard_df.loc[billboard_df['Name']].str.contains('How Deep is your Love', case=False)

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
#Weeks_on_chart, has unique artist/song name combo of songs that hit number one with the total number of weeks 
# they spent on the charts Break that down by year and Viz

# Could show averages and max by year

# %%
all_songs.head()
# Out:
#                                       top_spot  avg_weekly_rank  total_weeks  \
# Name                    Artists
# '03 Bonnie & Clyde      Jay                4.0        16.478261         23.0
# ...Ready For It?        Taylor Swift       4.0        41.736842         20.0
# 0 To 100 / The Catch Up Drake             35.0        48.000000         20.0
# 1                       800                3.0        34.414634         42.0
# 1 Thing                 Amerie             8.0        38.900000         20.0
#
#                                       year
# Name                    Artists
# '03 Bonnie & Clyde      Jay           2002
# ...Ready For It?        Taylor Swift  2017
# 0 To 100 / The Catch Up Drake         2014
# 1                       800           2017
# 1 Thing                 Amerie        2005

# %%
#getting a visual of how many songs hit the top 100 lsit by year. Need to investigate why there are so many for 
# 2018/2019 possible outlier there. 

sns.histplot(data=all_songs, x="year")
# Out:
# <AxesSubplot:xlabel='year', ylabel='Count'>

# %%
all_total_weeks.head()
# Out:
#                                      chart_debut_year  total_weeks_on_chart  \
# Name                Artists
# Radioactive         Imagine Dragons              2012                  87.0
# Sail                AWOLNATION                   2011                  79.0
# I'm Yours           Jason Mraz                   2008                  76.0
# Counting Stars      OneRepublic                  2013                  68.0
# Rolling In The Deep Adele                        2010                  65.0
#
#                                      top_position
# Name                Artists
# Radioactive         Imagine Dragons           3.0
# Sail                AWOLNATION               17.0
# I'm Yours           Jason Mraz                6.0
# Counting Stars      OneRepublic               2.0
# Rolling In The Deep Adele                     1.0

# %%
sns.scatterplot(data=all_total_weeks, x="top_position", y="total_weeks_on_chart")
# Out:
# <AxesSubplot:xlabel='top_position', ylabel='total_weeks_on_chart'>

# %%
sns.scatterplot(data=all_songs, x="top_spot", y="avg_weekly_rank")
# Out:
# <AxesSubplot:xlabel='top_spot', ylabel='avg_weekly_rank'>

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
# 2. Do you have any concerns about your dataset?
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
